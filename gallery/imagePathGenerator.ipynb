# %%
import os

# %%
root = os.getcwd()
print(root)
# Out:
# /Users/amrk/Documents/GitHub/album/gallery

# %%
path = "archive/Day3/"
filList = list()
for item in os.listdir(path):
    filList.append(item)
filList = sorted(filList)
for item in filList:
    if item.endswith(".jpg"):
        print(" - image_path: /gallery/"+path+item)
        print("   caption: Day 3")
        print("   copyright: ISCLS")
# Out:
#  - image_path: /gallery/archive/Day3/IMG_000.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_001.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_002.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_003.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_004.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_005.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_006.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_007.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_008.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_009.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day3/IMG_010.jpg
# ...
