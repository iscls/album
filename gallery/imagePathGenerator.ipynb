# %%
import os

# %%
root = os.getcwd()
print(root)
# Out:
# /Users/amrk/Documents/GitHub/album/gallery

# %%
path = "archive/Day2/"

# %%
for item in os.listdir(path):
    print(" - image_path: /gallery/"+path+item)
    print("   caption: Day 3")
    print("   copyright: ISCLS")
# Out:
#  - image_path: /gallery/archive/Day2/IMG_063.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_077.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_076.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_062.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_048.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_074.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_060.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_061.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_075.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_049.jpg
#    caption: Day 3
#    copyright: ISCLS
#  - image_path: /gallery/archive/Day2/IMG_071.jpg
# ...
